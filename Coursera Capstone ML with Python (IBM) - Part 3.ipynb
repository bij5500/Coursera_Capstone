# %% [markdown]
# ### 1. This is the code for the Capstone Project - Coursera (IBM ML With Python)

# %%
# start by importing the relevant libraries
import pandas as pd
from  bs4 import BeautifulSoup as bs
import json
import requests
from pandas.io.json import json_normalize

# %% [markdown]
# ### 2. Set the url and read the data from the website

# %%
# initialise and set the url variable from which data is to be scraped

url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
data = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
data_list = bs(data, 'html.parser')

# %% [markdown]
# ### 3. Setup the dataframe

# %%
#setup the column headers in the Dataframe
df_list = pd.DataFrame (columns = ['Postcode', 'Borough','Neighbourhood'])

# populate the dataframe
for row in data_list.find('table').find_all('tr'):
    cells = row.find_all('td')
    if(len(cells) > 0):
        check_str = cells[1].text

# ignore all lines that have Borough set to "Not Assigned"
        if check_str.find ("Not assigned") == -1:
            new_row = {'Postcode':cells[0].text, 'Borough':cells[1].text,'Neighbourhood':cells[2].text}
            df_list = df_list.append(new_row, ignore_index=True)

# %% [markdown]
# ### 4. Remove the /n characters from the data elements

# %%
# replace the /n characters being appended
df_list = df_list.replace('\n',' ', regex=True)

# %% [markdown]
# ### 5. Print the dataframe shape as per instructions

# %%
print(df_list.shape)
# Out:
# (103, 3)

# %% [markdown]
# ### 6. Before we start converting the post codes into latitude and longitude,  must install and import packages

# %%
# !pip install pgeocode
# !pip install folium
import pgeocode
import folium
from geopy.geocoders import Nominatim
import numpy as np
from sklearn.cluster import KMeans
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# Out:
# Requirement already satisfied: pgeocode in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.2.1)
# Requirement already satisfied: pandas in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pgeocode) (0.24.1)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pgeocode) (2.21.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pgeocode) (1.15.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pandas->pgeocode) (2.7.5)
# Requirement already satisfied: pytz>=2011k in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pandas->pgeocode) (2018.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->pgeocode) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->pgeocode) (2020.6.20)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->pgeocode) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->pgeocode) (1.24.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas->pgeocode) (1.12.0)
# Requirement already satisfied: folium in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.11.0)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (0.4.1)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)

# %% [markdown]
# ### 7. Now find the longtitude and latitude information

# %% [markdown]
# In this logic, we first obtain the location details for TORONTO.  As we process the postcodes, some are returned as NaN, which causes issues for the folium and mapping commands.  So, while inelegant, this code defaults to the Toront co-ordinates for any postcode that returns NaN.
#
# In this case I have used pgeocode rather than geocode or even the Excel sheet provided.  This is just so as to practice alternative approach to achieving the same effect.

# %%
#Start mapping - first create an initial map of the toronto Neighbourhood - this is located here as some postcodes are nulls.  In this case, the borough location is being defaulted to the Toronto location details.

address = 'Toronto'
gl = Nominatim(user_agent="govinda")
loc = gl.geocode(address)
lat = loc.latitude
long = loc.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(lat, long))

# Look up longitude and latitude using the poscode.  Using pgeocodes for this converison
nomi = pgeocode.Nominatim('ca')
pcodes = pd.DataFrame(columns= ['Postcode', 'Long','Lat'])

for index, row in df_list.iterrows():
    out = nomi.query_postal_code(row['Postcode'])
    if numpy.isnan(out[9]) or numpy.isnan(out[10]):
        new_row = {'Postcode':row['Postcode'], 'Long':long, 'Lat':lat}
    else:
        new_row = {'Postcode':row['Postcode'], 'Long':out[10], 'Lat':out[9]}
    pcodes = pcodes.append(new_row, ignore_index=True)
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# ### 8. Now merge the two DataFrames

# %%
#now merge the two dataframes

df_list_full = df_list.merge(pcodes, on='Postcode', how = 'left')

# print header to confirm that the data is updated correctly
print (df_list_full.head())
# Out:
#   Postcode            Borough                                 Neighbourhood  \
# 0     M3A         North York                                     Parkwoods
# 1     M4A         North York                              Victoria Village
# 2     M5A   Downtown Toronto                     Regent Park, Harbourfront
# 3     M6A         North York              Lawrence Manor, Lawrence Heights
# 4     M7A   Downtown Toronto   Queen's Park, Ontario Provincial Government
#
#       Long      Lat
# 0 -79.3300  43.7545
# 1 -79.3148  43.7276
# 2 -79.3626  43.6555
# 3 -79.4504  43.7223
# 4 -79.3889  43.6641

# %%
# filter borough names that contain the word Toronto
borough_names = list(df_list.Borough.unique())

borough_with_toronto = []

for x in borough_names:
    if "toronto" in x.lower():
        borough_with_toronto.append(x)
        
borough_with_toronto

# create a new DataFrame with only boroughs that contain the word Toronto
df_full_list = df_list_full[df_list_full['Borough'].isin(borough_with_toronto)].reset_index(drop=True)
print(df_list_full.shape)
df_list_full.head()
# Out:
# (103, 5)
#   Postcode            Borough                                 Neighbourhood  \
# 0     M3A         North York                                     Parkwoods
# 1     M4A         North York                              Victoria Village
# 2     M5A   Downtown Toronto                     Regent Park, Harbourfront
# 3     M6A         North York              Lawrence Manor, Lawrence Heights
# 4     M7A   Downtown Toronto   Queen's Park, Ontario Provincial Government
#
#       Long      Lat
# 0 -79.3300  43.7545
# 1 -79.3148  43.7276
# 2 -79.3626  43.6555
# 3 -79.4504  43.7223
# 4 -79.3889  43.6641

# %% [markdown]
# ### 9.  Now we start plotting the initial map to show the locations as identified above.  Using different fill colour for practice only.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[lat, long], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_list_full['Lat'], df_list_full['Long'], df_list_full['Borough'], df_list_full['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#000000',
        fill_opacity=0.7).add_to(map_toronto)

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 10. Now start formatting the 4Square query parameters - I have removed the CLIENT ID AND CLIENT SECRET FOR PUBLISHING TO GITHUB

# %%
#define Foursquare Credentials and Version
CLIENT_ID = 'CLIENT ID' # your Foursquare ID
CLIENT_SECRET = 'CLIENT SECRET' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
LIMIT = 100
radius = 450
# Out:
# Your credentails:
# CLIENT_ID: JMC0RA50DJHNPEPHWCHB4SDL5FJRAPX12WJRNAM2DYDP0GZJ
# CLIENT_SECRET:JO1TNVIKI4TNNZZ11NEIJDXS2FSCH0PUU1FC43TXOREDTP5T

# %% [markdown]
# ### 11. Retrieve data and create a new dataframe that shows the venue names by Borough and Neighbourhoods.  Add in the Lat, Long and Category

# %% [markdown]
# As an output print the number of Boroughs and Neighbour hoods

# %%
# set up output DataFrame
venue_data = pd.DataFrame (columns = ['Borough','Neighbourhood', 'VName', 'vLat', 'vLong', 'Category'])
x = 0
for lat, long, post, borough, neighborhood in zip(df_list_full['Lat'], df_list_full['Long'], df_list_full['Postcode'], df_list_full['Borough'], df_list_full['Neighbourhood']):
    url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}".format(
        CLIENT_ID,
        CLIENT_SECRET,
        VERSION,
        lat,
        long,
        radius,
        LIMIT)

    results = requests.get(url)
    test = results.json()
        
    group = test['response']['groups']
    for init_items in group:
        items = init_items['items']
        for get_names in items:
            cat_data = get_names['venue']['categories']
            for cat_name in cat_data:
                new_row = {'Borough': borough, 'Neighbourhood': neighborhood,'VName':get_names['venue']['name'], 'vLat':get_names['venue']['location']['lat'], 'vLong':get_names['venue']['location']['lng'], 'Category':cat_name['name']}
                venue_data = venue_data.append (new_row, ignore_index=True)

# print how many boroughs and neighborhoods counted
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(venue_data['Borough'].unique()),
        venue_data.shape[0]))
# Out:
# The dataframe has 10 boroughs and 1878 neighborhoods.

# %% [markdown]
# As a check lets print the first 10 lines of the newly formed data frame

# %%
print (venue_data.head(10))
# Out:
#              Borough               Neighbourhood  \
# 0        North York                   Parkwoods
# 1        North York                   Parkwoods
# 2        North York                   Parkwoods
# 3        North York            Victoria Village
# 4        North York            Victoria Village
# 5        North York            Victoria Village
# 6        North York            Victoria Village
# 7        North York            Victoria Village
# 8        North York            Victoria Village
# 9  Downtown Toronto   Regent Park, Harbourfront
#
#                                        VName       vLat      vLong  \
# 0                            Brookbanks Park  43.751976 -79.332140
# 1                              Variety Store  43.751974 -79.333114
# 2          Corrosion Service Company Limited  43.752432 -79.334661
# 3                                  Portugril  43.725819 -79.312785
# 4                                Tim Hortons  43.725517 -79.313103
# 5  Eglinton Ave E & Sloane Ave/Bermondsey Rd  43.726086 -79.313620
# 6                                   The Frig  43.727051 -79.317418
# 7                                 Pizza Nova  43.725824 -79.312860
# 8                                 Cash Money  43.725486 -79.312665
# 9                           Roselle Desserts  43.653447 -79.362017
#
#                      Category
# 0                        Park
# 1           Food & Drink Shop
# 2  Construction & Landscaping
# 3       Portuguese Restaurant
# 4                 Coffee Shop
# 5                Intersection
# 6           French Restaurant
# 7                 Pizza Place
# 8  Financial or Legal Service
# 9                      Bakery

# %% [markdown]
# ### 12 a) Explore the data - for this I want to know the count of each category type

# %%
venue_data.groupby(["Category"])["VName"].count()
# Out:
# Category
# Accessories Store                 2
# Afghan Restaurant                 2
# Airport                           1
# American Restaurant              23
# Art Gallery                       9
# Art Museum                        2
# Arts & Crafts Store               5
# Asian Restaurant                 16
# Athletics & Sports                3
# Auto Dealership                   1
# Auto Garage                       3
# BBQ Joint                         4
# Baby Store                        1
# Bagel Shop                        3
# Bakery                           32
# Bank                             25
# Bar                              24
# Baseball Field                    6
# Basketball Court                  1
# Basketball Stadium                2
# Beach Bar                         1
# Beer Bar                         11
# Beer Store                        7
# Belgian Restaurant                1
# Bike Rental / Bike Share          1
# Bistro                            4
# Bookstore                        14
# Boutique                          4
# Brazilian Restaurant              2
# Breakfast Spot                   21
#                                  ..
# Speakeasy                         5
# Sporting Goods Shop               7
# Sports Bar                        5
# Steakhouse                       19
# Strip Club                        1
# Supermarket                       6
# Sushi Restaurant                 30
# Taco Place                        3
# Tailor Shop                       2
# Tanning Salon                     3
# Tea Room                         20
# Tennis Court                      3
# Thai Restaurant                  18
# Theater                          13
# Theme Restaurant                  1
# Thrift / Vintage Store            3
# Toy / Game Store                  5
# Trail                             6
# Train Station                     2
# Turkish Restaurant                2
# Vegetarian / Vegan Restaurant    13
# Video Game Store                  5
# Video Store                       2
# Vietnamese Restaurant             8
# Warehouse Store                   1
# Whisky Bar                        1
# Wine Bar                          8
# Wine Shop                         2
# Women's Store                     7
# Yoga Studio                      10
# Name: VName, Length: 242, dtype: int64

# %% [markdown]
# ### 12 b) explore the data - list all the steakhouses

# %%
steak_house = venue_data.loc[venue_data['Category'] == 'Steakhouse']
print(steak_house)
# Out:
#                 Borough                              Neighbourhood  \
# 135   Downtown Toronto                   Garden District, Ryerson
# 398   Downtown Toronto                                Berczy Park
# 460   Downtown Toronto                         Central Bay Street
# 534   Downtown Toronto                   Richmond, Adelaide, King
# 562   Downtown Toronto                   Richmond, Adelaide, King
# 586   Downtown Toronto                   Richmond, Adelaide, King
# 820   Downtown Toronto   Toronto Dominion Centre, Design Exchange
# 862   Downtown Toronto   Toronto Dominion Centre, Design Exchange
# 930       East Toronto             India Bazaar, The Beaches West
# 947   Downtown Toronto             Commerce Court, Victoria Hotel
# 1007  Downtown Toronto             Commerce Court, Victoria Hotel
# 1019  Downtown Toronto             Commerce Court, Victoria Hotel
# 1100        North York                Willowdale, Willowdale East
# 1314       Mississauga      Canada Post Gateway Processing Centre
# 1579  Downtown Toronto                             Stn A PO Boxes
# 1690  Downtown Toronto     First Canadian Place, Underground city
# 1750  Downtown Toronto     First Canadian Place, Underground city
# 1762  Downtown Toronto     First Canadian Place, Underground city
# 1823  Downtown Toronto                       Church and Wellesley
#
#                          VName       vLat      vLong    Category
# 135    Barberian's Steak House  43.657755 -79.382177  Steakhouse
# 398         Harbour 60 Toronto  43.642220 -79.377945  Steakhouse
# 460    Barberian's Steak House  43.657755 -79.382177  Steakhouse
# 534            Hy's Steakhouse  43.649505 -79.382919  Steakhouse
# 562   Ruth's Chris Steak House  43.649917 -79.385724  Steakhouse
# 586        Michael's on Simcoe  43.648269 -79.386328  Steakhouse
# 820            Hy's Steakhouse  43.649505 -79.382919  Steakhouse
# 862   Ruth's Chris Steak House  43.649917 -79.385724  Steakhouse
# 930       The Tulip Steakhouse  43.666348 -79.316854  Steakhouse
# 947            Hy's Steakhouse  43.649505 -79.382919  Steakhouse
# 1007  Ruth's Chris Steak House  43.649917 -79.385724  Steakhouse
# 1019       Michael's on Simcoe  43.648269 -79.386328  Steakhouse
# 1100                   The Keg  43.766579 -79.412131  Steakhouse
# 1314           Hy's Steakhouse  43.649505 -79.382919  Steakhouse
# 1579        Harbour 60 Toronto  43.642220 -79.377945  Steakhouse
# 1690           Hy's Steakhouse  43.649505 -79.382919  Steakhouse
# 1750  Ruth's Chris Steak House  43.649917 -79.385724  Steakhouse
# 1762       Michael's on Simcoe  43.648269 -79.386328  Steakhouse
# 1823  The Keg Steakhouse + Bar  43.666756 -79.378302  Steakhouse

# %% [markdown]
# #### Mapping the steakhouses - just for fun :)

# %%
# create map of Toronto using latitude and longitude values
map_steakhouses = folium.Map(location=[lat, long], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(steak_house['vLat'], steak_house['vLong'], steak_house['Borough'], steak_house['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#000000',
        fill_opacity=0.7).add_to(map_steakhouses)

map_steakhouses
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ###  13  Now set up the cluster groups - I initially did three clusters but later changed to 4.  This was just for me to see how this worked

# %%
# set number of clusters
kclusters = 4

venue_data_interim = venue_data
venue_grouped_clustering = venue_data_interim.drop(['Neighbourhood','Category','VName','Borough'], 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(venue_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 1], dtype=int32)

# %% [markdown]
# Run the clustering

# %%
venue_data_sorted = venue_data.sort_values (by=['Neighbourhood'])

venue_data_sorted["Cluster Labels"] = kmeans.labels_

venue_data_sorted.head(20)
# Out:
#            Borough                                     Neighbourhood  \
# 1347  Scarborough                                         Agincourt
# 1348  Scarborough                                         Agincourt
# 1644    Etobicoke                            Alderwood, Long Branch
# 1643    Etobicoke                            Alderwood, Long Branch
# 1642    Etobicoke                            Alderwood, Long Branch
# 1641    Etobicoke                            Alderwood, Long Branch
# 1639    Etobicoke                            Alderwood, Long Branch
# 1640    Etobicoke                            Alderwood, Long Branch
# 492    North York   Bathurst Manor, Wilson Heights, Downsview North
# 491    North York   Bathurst Manor, Wilson Heights, Downsview North
# 490    North York   Bathurst Manor, Wilson Heights, Downsview North
# 495    North York   Bathurst Manor, Wilson Heights, Downsview North
# 494    North York   Bathurst Manor, Wilson Heights, Downsview North
# 493    North York   Bathurst Manor, Wilson Heights, Downsview North
# 764    North York                                   Bayview Village
# 762    North York                                   Bayview Village
# 761    North York                                   Bayview Village
# 760    North York                                   Bayview Village
# 763    North York                                   Bayview Village
# 1073   North York                 Bedford Park, Lawrence Manor East
#
#                                  VName       vLat      vLong  \
# 1347       Panagio's Breakfast & Lunch  43.792370 -79.260203
# 1348                   Commander Arena  43.794867 -79.267989
# 1644                            Rexall  43.601951 -79.545694
# 1643                     Delta Variety  43.603897 -79.536385
# 1642                       Tim Hortons  43.602396 -79.545048
# 1641                     Timothy's Pub  43.600165 -79.544699
# 1639  Il Paesano Pizzeria & Restaurant  43.601280 -79.545028
# 1640  Toronto Gymnastics International  43.599832 -79.542924
# 492            Orly Restaurant & Grill  43.754493 -79.443507
# 491                      Wolfie's Deli  43.754875 -79.442438
# 490                         Grill Gate  43.753123 -79.451690
# 495                     Domino's Pizza  43.753127 -79.450926
# 494          Popeyes Louisiana Kitchen  43.754671 -79.442740
# 493                        Tim Hortons  43.754767 -79.443250
# 764                           The Park  43.783171 -79.383108
# 762                       Petro-Canada  43.776510 -79.380200
# 761                    Royal Frenchies  43.777059 -79.382422
# 760                       Forest Grove  43.779341 -79.379326
# 763            Flowers & Blossoms Inc.  43.776827 -79.378152
# 1073                         Starbucks  43.732604 -79.419136
#
#                        Category  Cluster Labels
# 1347             Breakfast Spot               2
# 1348               Skating Rink               2
# 1644                   Pharmacy               2
# 1643          Convenience Store               2
# 1642                Coffee Shop               2
# 1641                        Pub               2
# 1639                Pizza Place               2
# 1640                        Gym               2
# 492   Middle Eastern Restaurant               2
# 491               Deli / Bodega               1
# 490    Mediterranean Restaurant               1
# 495                 Pizza Place               1
# 494         Fried Chicken Joint               1
# 493                 Coffee Shop               1
# 764                        Park               1
# 762                 Gas Station               1
# 761                     Dog Run               1
# 760                       Trail               1
# 763                 Flower Shop               1
# 1073                Coffee Shop               1

# %% [markdown]
# ###  14 Map the clusters using folium

# %%
# create map
map_clusters = folium.Map(location=[lat, long], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(venue_data_sorted['vLat'], venue_data_sorted['vLong'], venue_data_sorted['Neighbourhood'], venue_data_sorted['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 15 Examine the clusters - only printing the first 10 points.  In this case I have chosen not to out the data with Category ratings

# %%
venue_clustered = venue_data_sorted.loc[venue_data_sorted['Cluster Labels'] == 0, venue_data_sorted.columns[[1] + list(range(5, venue_data_sorted.shape[1]))]]
venue_clustered.groupby(['Neighbourhood','Category']).count()
venue_clustered.head(10)
# Out:
#                                Neighbourhood                    Category  \
# 366                             Berczy Park                   Food Truck
# 1097            Birch Cliff, Cliffside West        General Entertainment
# 1096            Birch Cliff, Cliffside West                         Café
# 1098            Birch Cliff, Cliffside West                 Skating Rink
# 1313  Canada Post Gateway Processing Centre                         Bank
# 1312  Canada Post Gateway Processing Centre   Modern European Restaurant
# 1311  Canada Post Gateway Processing Centre               Clothing Store
# 1310  Canada Post Gateway Processing Centre                          Bar
# 1309  Canada Post Gateway Processing Centre                 Dessert Shop
# 1824                   Church and Wellesley                Burrito Place
#
#       Cluster Labels
# 366                0
# 1097               0
# 1096               0
# 1098               0
# 1313               0
# 1312               0
# 1311               0
# 1310               0
# 1309               0
# 1824               0

# %%
venue_clustered = venue_data_sorted.loc[venue_data_sorted['Cluster Labels'] == 1, venue_data_sorted.columns[[1] + list(range(5, venue_data_sorted.shape[1]))]]
venue_clustered.groupby(['Neighbourhood','Category']).count()
venue_clustered.head(10)
# Out:
#                                         Neighbourhood  \
# 491  Bathurst Manor, Wilson Heights, Downsview North
# 490  Bathurst Manor, Wilson Heights, Downsview North
# 495  Bathurst Manor, Wilson Heights, Downsview North
# 494  Bathurst Manor, Wilson Heights, Downsview North
# 493  Bathurst Manor, Wilson Heights, Downsview North
# 764                                  Bayview Village
# 762                                  Bayview Village
# 761                                  Bayview Village
# 760                                  Bayview Village
# 763                                  Bayview Village
#
#                      Category  Cluster Labels
# 491             Deli / Bodega               1
# 490  Mediterranean Restaurant               1
# 495               Pizza Place               1
# 494       Fried Chicken Joint               1
# 493               Coffee Shop               1
# 764                      Park               1
# 762               Gas Station               1
# 761                   Dog Run               1
# 760                     Trail               1
# 763               Flower Shop               1

# %%
venue_clustered = venue_data_sorted.loc[venue_data_sorted['Cluster Labels'] == 2, venue_data_sorted.columns[[1] + list(range(5, venue_data_sorted.shape[1]))]]
venue_clustered.groupby(['Neighbourhood','Category']).count()
venue_clustered.head(10)
# Out:
#                                          Neighbourhood  \
# 1347                                        Agincourt
# 1348                                        Agincourt
# 1644                           Alderwood, Long Branch
# 1643                           Alderwood, Long Branch
# 1642                           Alderwood, Long Branch
# 1641                           Alderwood, Long Branch
# 1639                           Alderwood, Long Branch
# 1640                           Alderwood, Long Branch
# 492   Bathurst Manor, Wilson Heights, Downsview North
# 1099                      Birch Cliff, Cliffside West
#
#                        Category  Cluster Labels
# 1347             Breakfast Spot               2
# 1348               Skating Rink               2
# 1644                   Pharmacy               2
# 1643          Convenience Store               2
# 1642                Coffee Shop               2
# 1641                        Pub               2
# 1639                Pizza Place               2
# 1640                        Gym               2
# 492   Middle Eastern Restaurant               2
# 1099            College Stadium               2
